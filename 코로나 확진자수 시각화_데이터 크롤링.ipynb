# %%
import pandas as pd
import numpy as np

# %%
url= "https://www.seoul.go.kr/coronaV/coronaStatus.do"
url
# Out:
# 'https://www.seoul.go.kr/coronaV/coronaStatus.do'

# %%
table=pd.read_html(url)
len(table)
# Out:
# 6

# %%
table[0].transpose()
# Out:
#                 0
# 소계           1416
# 해외접촉관련        319
# 강남역삼동금융회사관련     8
# 관악구왕성교회관련      30
# 강남구사무실관련        7
# 강남구역삼동모임       12
# 도봉구요양시설관련      43
# 리치웨이관련        122
# 부천시쿠팡관련        24
# 수도권개척교회관련      37
# 양천구운동시설관련      43
# 이태원클럽관련       139
# 구로구콜센터관련       98
# 타 시·도확진자접촉자    50
# 기타            343
# 경로확인중         141

# %%
df =table[4]
df.shape
# Out:
# (1416, 7)

# %%
df.head()
# Out:
#      연번     환자    확진일   거주지 여행력         접촉력     조치사항
# 0  1416  13412  7.11.   강동구   -        확인 중    서울의료원
# 1  1415  13396  7.11.   강동구   -        확인 중  한양대학교병원
# 2  1414  13398  7.11.   중랑구   -        확인 중    서울의료원
# 3  1413  13393  7.11.   강남구   -  양천구 확진자 접촉    서울의료원
# 4  1412  13390  7.11.  영등포구   -  강서구 확진자 접촉    보라매병원

# %%
last_day = df.loc[0,"확진일"]
last_day =last_day.replace(".","_")
last_day
# Out:
# '7_11_'

# %%
file_name =f"seoul-covid19_{last_day}.csv" 
file_name
# Out:
# 'seoul-covid19_7_11_.csv'

# %%
df.to_csv(file_name)

# %%
df.head()
# Out:
#      연번     환자    확진일   거주지 여행력         접촉력     조치사항
# 0  1416  13412  7.11.   강동구   -        확인 중    서울의료원
# 1  1415  13396  7.11.   강동구   -        확인 중  한양대학교병원
# 2  1414  13398  7.11.   중랑구   -        확인 중    서울의료원
# 3  1413  13393  7.11.   강남구   -  양천구 확진자 접촉    서울의료원
# 4  1412  13390  7.11.  영등포구   -  강서구 확진자 접촉    보라매병원

# %%
pd.read_csv(file_name)
# Out:
#       Unnamed: 0    연번     환자    확진일   거주지     여행력         접촉력         조치사항
# 0              0  1416  13412  7.11.   강동구       -        확인 중        서울의료원
# 1              1  1415  13396  7.11.   강동구       -        확인 중      한양대학교병원
# 2              2  1414  13398  7.11.   중랑구       -        확인 중        서울의료원
# 3              3  1413  13393  7.11.   강남구       -  양천구 확진자 접촉        서울의료원
# 4              4  1412  13390  7.11.  영등포구       -  강서구 확진자 접촉        보라매병원
# ...          ...   ...    ...    ...   ...     ...         ...          ...
# 1411        1411     5      9  1.31.   성북구       -       #5 접촉    서울의료원(퇴원)
# 1412        1412     4      7  1.30.   마포구  중국 우한시       해외 접촉    서울의료원(퇴원)
# 1413        1413     3      6  1.30.   종로구       -       #3 접촉  서울대학교병원(퇴원)
# 1414        1414     2      5  1.30.   중랑구  중국 우한시       해외 접촉    서울의료원(퇴원)
# 1415        1415     1      2  1.24.   강서구  중국 우한시       해외 접촉  국립중앙의료원(퇴원)
#
# [1416 rows x 8 columns]

# %%
df.to_csv(file_name, index=False)

# %%
pd.read_csv(file_name)
# Out:
#         연번     환자    확진일   거주지     여행력         접촉력         조치사항
# 0     1416  13412  7.11.   강동구       -        확인 중        서울의료원
# 1     1415  13396  7.11.   강동구       -        확인 중      한양대학교병원
# 2     1414  13398  7.11.   중랑구       -        확인 중        서울의료원
# 3     1413  13393  7.11.   강남구       -  양천구 확진자 접촉        서울의료원
# 4     1412  13390  7.11.  영등포구       -  강서구 확진자 접촉        보라매병원
# ...    ...    ...    ...   ...     ...         ...          ...
# 1411     5      9  1.31.   성북구       -       #5 접촉    서울의료원(퇴원)
# 1412     4      7  1.30.   마포구  중국 우한시       해외 접촉    서울의료원(퇴원)
# 1413     3      6  1.30.   종로구       -       #3 접촉  서울대학교병원(퇴원)
# 1414     2      5  1.30.   중랑구  중국 우한시       해외 접촉    서울의료원(퇴원)
# 1415     1      2  1.24.   강서구  중국 우한시       해외 접촉  국립중앙의료원(퇴원)
#
# [1416 rows x 7 columns]

# %%
pip install jupyter_contrib_nbextensions && jupyter contrib nbextension install
# Out:
# /bin/sh: pip: command not found
